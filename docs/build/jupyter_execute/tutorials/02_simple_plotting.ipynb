# %% [markdown]
# # Tutorial 2: Simple plotting
#
# This tutorial sketches how to create a simple 2D plot from a 3D DNS
# field using the plotting utilities provided by **aPrioriDNS**.
#
# It is intentionally lightweight so it can serve as a template for your
# real plotting tutorials.

# %%
import aPrioriDNS as ap
from aPrioriDNS.DNS import Field3D

# You will need matplotlib installed to actually run the plotting parts.
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load a case and field
#
# Replace the placeholder case name and variable with the ones you use in
# your production tutorials.

# %%
# ap.download("Lifted_H2_subdomain")

# field = Field3D("Lifted_H2_subdomain")
# T = field["T"]  # temperature scalar field

# %% [markdown]
# ## 2. Plot a mid-plane slice
#
# Here we just outline a typical plotting call; adapt it to match the
# real API of your `Field3D`/`Scalar3D` classes and plotting utilities.

# %%
# Example, adjust to your actual implementation:

# field.plot_z_midplane(
#     "T",
#     levels=[1400, 2000],
#     vmin=1400,
#     title="T [K]",
#     linewidth=2,
#     transpose=True,
#     x_name="y [mm]",
#     y_name="x [mm]",
# )

# plt.show()
