# %% [markdown]
# # Tutorial 1: Basic field operations
#
# This short tutorial demonstrates how to:
#
# 1. Import **aPrioriDNS**
# 2. Download or load a sample DNS dataset
# 3. Create a `Field3D` object
# 4. Compute a simple derived quantity
#
# You can run this notebook locally or simply read it in the Sphinx documentation.

# %%
# If you are running this notebook locally, make sure aPrioriDNS is installed.
# For example:
# !pip install aPrioriDNS

import aPrioriDNS as ap
from aPrioriDNS.DNS import Field3D

print(f"aPrioriDNS version: {getattr(ap, '__version__', 'unknown')}")
# Out:
# aPrioriDNS version: 1.11.0

# %% [markdown]
# ## 1. Load or download a DNS case
#
# For real analysis you would typically download a dataset or point the
# library to an existing one. Here we just sketch the call; adapt the
#                 paths and options to your own environment.

# %%
# This is a placeholder example; replace with an actual dataset name
# when you prepare your real tutorials.

# ap.download("Lifted_H2_subdomain")

# Once the dataset is available, you can create a Field3D object.
# Here we assume that the case name is 'Lifted_H2_subdomain'.

# field = Field3D("Lifted_H2_subdomain")
# field

# %% [markdown]
# ## 2. Compute a derived quantity
#
# Again, this is a placeholder for your future tutorial. Replace it with
# a real operation you want to showcase (e.g. temperature statistics,
# mixture fraction, conditional averages, etc.).

# %%
# Example sketch of a computation:

# T = field["T"]  # temperature field (Scalar3D)
# T_mean = T.mean()
# print("Mean temperature:", T_mean)
